# %%
print('Hello')
# Out:
# Hello

# %%
import tensorflow as tf

mnist = tf.keras.datasets.fashion_mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

x_train = tf.keras.utils.normalize(x_train, axis=1)
x_test = tf.keras.utils.normalize(x_test, axis=1)

model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(128, activation=tf.nn.relu))
model.add(tf.keras.layers.Dense(10, activation=tf.nn.softmax))

model.compile(optimizer='adam',
             loss='sparse_categorical_crossentropy',
             metrics=['accuracy'])
model.fit(x_train, y_train, epochs=5)
# Out:
# Train on 60000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 6s 98us/sample - loss: 0.4901 - accuracy: 0.8202
# Epoch 2/5
# 60000/60000 [==============================] - 5s 85us/sample - loss: 0.3545 - accuracy: 0.8692
# Epoch 3/5
# 60000/60000 [==============================] - 5s 82us/sample - loss: 0.3187 - accuracy: 0.8813
# Epoch 4/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.2949 - accuracy: 0.8885
# Epoch 5/5
# 60000/60000 [==============================] - 5s 83us/sample - loss: 0.2746 - accuracy: 0.8964

# %%
import matplotlib.pyplot as plt

plt.imshow(x_train[0], cmap=plt.cm.binary)
plt.show()

# %%
val_loss, val_acc = model.evaluate(x_test, y_test)
print(val_loss, val_acc)
# Out:
# 10000/1 [======================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================================= ...
# 0.3418800205230713 0.8767

# %%
plt.imshow(x_test[0])
plt.show()

# %%
predictions = model.predict([x_test])

# %%
print(predictions)
# Out:
# [[4.7517883e-06 1.7238433e-08 4.9413138e-06 ... 2.9359472e-03
#   4.1538169e-07 9.9686450e-01]
#  [3.5185521e-04 4.4024196e-07 9.6592164e-01 ... 4.2079908e-09
#   8.7135622e-06 5.9099103e-09]
#  [3.7155100e-05 9.9995184e-01 4.0087093e-07 ... 1.1761400e-09
#   3.1540733e-07 8.3359264e-11]
#  ...
#  [2.7464400e-04 9.7193720e-07 5.5757901e-05 ... 2.1293140e-07
#   9.9902809e-01 2.6884777e-09]
#  [4.0934387e-06 9.9977773e-01 2.2141573e-06 ... 3.7525962e-07
#   1.6465115e-06 2.3301009e-08]
#  [7.9038455e-07 3.8545296e-09 3.6605488e-05 ... 4.1191728e-05
#   1.9026891e-04 1.2027991e-07]]

# %%
import numpy as np

print(np.argmax(predictions[0]))
# Out:
# 9
